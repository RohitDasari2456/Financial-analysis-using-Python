# %%
# !pip install yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=f2b6a7b7e871f7c7e5a4789266b12a6f9816067faff282283d4d0d144d6187a2
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/aa/8a/36/59ed4f6fbcb6100967618eeb0696046bf9777a41ac2ff1f9b9
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8366 sha256=ecb3f05ccf81779de4885dc8f6da9148ada1a394936eb5aab93a3c64329f2c74
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/ae/25/47/4d68431a7ec1b6c4b5233365934b74c1d4e665bf5f968d363a
# Successfully built yfinance multitasking
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf

# %%
tata = yf.download("TATAMOTORS.NS" , start='2019-01-01', end='2021-02-01', groupby='ticker')
hero = yf.download("HEROMOTOCO.NS" , start='2019-01-01', end='2021-02-01', groupby='ticker')
eicher = yf.download("EICHERMOT.NS" , start='2019-01-01', end='2021-02-01', groupby='ticker')
tvs = yf.download(".NS" , start='2019-01-01', end='2021-02-01', groupby='ticker')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tvs
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01  570.000000  573.750000  561.200012  564.549988  556.477173
# 2019-01-02  564.400024  575.650024  531.000000  535.250000  527.596130
# 2019-01-03  535.000000  544.599976  532.750000  537.849976  530.158997
# 2019-01-04  537.000000  545.900024  535.650024  540.950012  533.214661
# 2019-01-07  543.700012  545.700012  533.349976  534.750000  527.103333
# ...                ...         ...         ...         ...         ...
# 2021-01-22  514.000000  535.000000  512.049988  521.950012  520.250244
# 2021-01-25  532.950012  548.049988  519.349976  542.750000  540.982483
# 2021-01-27  543.000000  555.549988  526.799988  531.500000  529.769165
# 2021-01-28  523.900024  534.650024  521.099976  529.099976  527.376953
# 2021-01-29  552.500000  589.750000  552.099976  560.700012  558.874084
#
#               Volume
# Date
# 2019-01-01    525625
# 2019-01-02   3650090
# 2019-01-03   1447966
# ...

# %%
stocks = pd.concat([tata['Close'],hero['Close'],tvs['Close'],eicher['Close']],axis=1)

# %%
stocks
# Out:
#                  Close        Close       Close        Close
# Date
# 2019-01-01  173.449997  3127.600098  564.549988  2319.510010
# 2019-01-02  168.550003  3046.550049  535.250000  2116.229980
# 2019-01-03  166.050003  3014.649902  537.849976  2021.145020
# 2019-01-04  170.949997  2987.850098  540.950012  2010.359985
# 2019-01-07  175.350006  2957.949951  534.750000  1983.040039
# ...                ...          ...         ...          ...
# 2021-01-22  289.350006  3374.899902  521.950012  2972.600098
# 2021-01-25  279.149994  3474.949951  542.750000  2869.550049
# 2021-01-27  267.500000  3358.550049  531.500000  2789.899902
# 2021-01-28  266.799988  3397.399902  529.099976  2798.449951
# 2021-01-29  262.700012  3256.050049  560.700012  2744.300049
#
# [512 rows x 4 columns]

# %%
stocks.columns = ['TATA Close','HERO Close','TVS Close','EICHER Close']

# %%
stocks
# Out:
#             TATA Close   HERO Close   TVS Close  EICHER Close
# Date
# 2019-01-01  173.449997  3127.600098  564.549988   2319.510010
# 2019-01-02  168.550003  3046.550049  535.250000   2116.229980
# 2019-01-03  166.050003  3014.649902  537.849976   2021.145020
# 2019-01-04  170.949997  2987.850098  540.950012   2010.359985
# 2019-01-07  175.350006  2957.949951  534.750000   1983.040039
# ...                ...          ...         ...           ...
# 2021-01-22  289.350006  3374.899902  521.950012   2972.600098
# 2021-01-25  279.149994  3474.949951  542.750000   2869.550049
# 2021-01-27  267.500000  3358.550049  531.500000   2789.899902
# 2021-01-28  266.799988  3397.399902  529.099976   2798.449951
# 2021-01-29  262.700012  3256.050049  560.700012   2744.300049
#
# [512 rows x 4 columns]

# %%
daily_ret = stocks.pct_change(1)

# %%
daily_ret.head()
# Out:
#             TATA Close  HERO Close  TVS Close  EICHER Close
# Date
# 2019-01-01         NaN         NaN        NaN           NaN
# 2019-01-02   -0.028250   -0.025914  -0.051900     -0.087639
# 2019-01-03   -0.014832   -0.010471   0.004857     -0.044931
# 2019-01-04    0.029509   -0.008890   0.005764     -0.005336
# 2019-01-07    0.025739   -0.010007  -0.011461     -0.013590

# %%
daily_ret2 = stocks.pct_change(2)
daily_ret2.head()
# Out:
#             TATA Close  HERO Close  TVS Close  EICHER Close
# Date
# 2019-01-01         NaN         NaN        NaN           NaN
# 2019-01-02         NaN         NaN        NaN           NaN
# 2019-01-03   -0.042664   -0.036114  -0.047294     -0.128633
# 2019-01-04    0.014239   -0.019268   0.010649     -0.050028
# 2019-01-07    0.056007   -0.018808  -0.005764     -0.018853

# %%
mean_daily_ret = daily_ret.mean()
mean_daily_ret
# Out:
# TATA Close      0.001575
# HERO Close      0.000371
# TVS Close       0.000296
# EICHER Close    0.000661
# dtype: float64

# %%
Correlation = daily_ret.corr()
Correlation
# Out:
#               TATA Close  HERO Close  TVS Close  EICHER Close
# TATA Close      1.000000    0.384285   0.442658      0.398754
# HERO Close      0.384285    1.000000   0.599336      0.501020
# TVS Close       0.442658    0.599336   1.000000      0.546134
# EICHER Close    0.398754    0.501020   0.546134      1.000000

# %% [markdown]
# # Simulating Thousands of Possible Allocations

# %%
stock_normed = stocks/stocks.iloc[0]
stock_normed
# Out:
#             TATA Close  HERO Close  TVS Close  EICHER Close
# Date
# 2019-01-01    1.000000    1.000000   1.000000      1.000000
# 2019-01-02    0.971750    0.974086   0.948100      0.912361
# 2019-01-03    0.957336    0.963886   0.952706      0.871367
# 2019-01-04    0.985587    0.955317   0.958197      0.866718
# 2019-01-07    1.010954    0.945757   0.947215      0.854939
# ...                ...         ...        ...           ...
# 2021-01-22    1.668204    1.079070   0.924542      1.281564
# 2021-01-25    1.609398    1.111060   0.961385      1.237136
# 2021-01-27    1.542231    1.073843   0.941458      1.202797
# 2021-01-28    1.538195    1.086264   0.937207      1.206483
# 2021-01-29    1.514558    1.041070   0.993180      1.183138
#
# [512 rows x 4 columns]

# %%
stock_normed.plot(figsize=(14,7))

# %% [markdown]
# # Log Returns vs Arithmetic Returns

# %%
log_ret = np.log(stocks/stocks.shift(1))
log_ret
# Out:
#             TATA Close  HERO Close  TVS Close  EICHER Close
# Date
# 2019-01-01         NaN         NaN        NaN           NaN
# 2019-01-02   -0.028657   -0.026256  -0.053295     -0.091720
# 2019-01-03   -0.014943   -0.010526   0.004846     -0.045972
# 2019-01-04    0.029082   -0.008930   0.005747     -0.005350
# 2019-01-07    0.025413   -0.010058  -0.011528     -0.013683
# ...                ...         ...        ...           ...
# 2021-01-22   -0.004311    0.038542   0.023946      0.015596
# 2021-01-25   -0.035888    0.029214   0.039077     -0.035282
# 2021-01-27   -0.042630   -0.034071  -0.020946     -0.028150
# 2021-01-28   -0.002620    0.011501  -0.004526      0.003060
# 2021-01-29   -0.015487   -0.042496   0.058009     -0.019540
#
# [512 rows x 4 columns]

# %%
log_ret.hist(bins=100 ,figsize=(12,6))
plt.tight_layout()

# %%
log_ret.plot(kind='line', figsize=(16,8))
plt.tight_layout()

# %%
log_ret.describe().transpose()
# Out:
#               count      mean       std       min       25%       50%  \
# TATA Close    511.0  0.000812  0.038833 -0.193375 -0.019240 -0.000509
# HERO Close    511.0  0.000079  0.024188 -0.116517 -0.012932  0.000146
# TVS Close     511.0 -0.000013  0.024913 -0.136470 -0.013033 -0.001017
# EICHER Close  511.0  0.000329  0.025805 -0.134461 -0.012712  0.001423
#
#                    75%       max
# TATA Close    0.016992  0.307102
# HERO Close    0.012939  0.122727
# TVS Close     0.012099  0.128064
# EICHER Close  0.013602  0.125576

# %%
log_ret.mean()*252
# Out:
# TATA Close      0.204718
# HERO Close      0.019849
# TVS Close      -0.003375
# EICHER Close    0.082933
# dtype: float64

# %%
log_ret.cov()
# Out:
#               TATA Close  HERO Close  TVS Close  EICHER Close
# TATA Close      0.001508    0.000369   0.000436      0.000411
# HERO Close      0.000369    0.000585   0.000362      0.000314
# TVS Close       0.000436    0.000362   0.000621      0.000352
# EICHER Close    0.000411    0.000314   0.000352      0.000666

# %%
log_ret.cov()*252
# Out:
#               TATA Close  HERO Close  TVS Close  EICHER Close
# TATA Close      0.380010    0.092947   0.109871      0.103623
# HERO Close      0.092947    0.147437   0.091240      0.079075
# TVS Close       0.109871    0.091240   0.156405      0.088738
# EICHER Close    0.103623    0.079075   0.088738      0.167810

# %%
weights = np.array(np.random.random(21))
weights
# Out:
# array([0.13894005, 0.68472477, 0.88318637, 0.39226394, 0.66500432,
#        0.86282801, 0.30171261, 0.7378268 , 0.17460626, 0.22026608,
#        0.69626867, 0.57149033, 0.339113  , 0.13391971, 0.65430295,
#        0.56805361, 0.42351602, 0.99120076, 0.39905798, 0.41314293,
#        0.79769031])

# %%
weights.T
# Out:
# array([0.40122278, 0.44338777, 0.02212343, 0.13326603])

# %%
np.random.seed(101)

# Stock Columns
print('Stocks')
print(stocks.columns)
print('\n')

# Create Random Weights
print('Creating Random Weights')
weights = np.array(np.random.random(4))
print(weights)
print('\n')

# Rebalance Weights
print('Rebalance to sum to 1.0')
weights = weights / np.sum(weights)
print(weights)
print('\n')

# Expected Return
print('Expected Portfolio Return')
exp_ret = np.sum((log_ret.mean() * weights)*252)
print(exp_ret)
print('\n')

# Expected Variance
print('Expected Volatility')
exp_vol = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
print(exp_vol)
print('\n')

# Sharpe Ratio
SR = exp_ret/exp_vol
print('Sharpe Ratio')
print(SR)
# Out:
# Stocks
# Index(['TATA Close', 'HERO Close', 'TVS Close', 'EICHER Close'], dtype='object')
#
#
# Creating Random Weights
# [0.51639863 0.57066759 0.02847423 0.17152166]
#
#
# Rebalance to sum to 1.0
# [0.40122278 0.44338777 0.02212343 0.13326603]
#
#
# Expected Portfolio Return
# 0.10191589035817622
#
#
# Expected Volatility
# 0.388555824346968
#
#
# Sharpe Ratio
# 0.2622940745501953

# %%
num_ports = 20000

all_weights = np.zeros((num_ports,len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for ind in range(num_ports):

    # Create Random Weights
    weights = np.array(np.random.random(4))

    # Rebalance Weights
    weights = weights / np.sum(weights)
    
    # Save Weights
    all_weights[ind,:] = weights

    # Expected Return
    ret_arr[ind] = np.sum((log_ret.mean() * weights) *252)

    # Expected Variance
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))

    # Sharpe Ratio
    sharpe_arr[ind] = ret_arr[ind]/vol_arr[ind]

# %%
sharpe_arr.max()
# Out:
# 0.3366639361799101

# %%
aa = sharpe_arr.argmax()

# %%
all_weights[aa,:]
# Out:
# array([0.65942696, 0.02696828, 0.00425818, 0.30934658])

# %%
max_sr_ret = ret_arr[aa]
max_sr_vol = vol_arr[aa]

# %% [markdown]
# # Plotting the data

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr,ret_arr,c=sharpe_arr,cmap='magma_r')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')

# Add red dot for max SR
plt.scatter(max_sr_vol,max_sr_ret,c='white',s=50,edgecolors='blue')

# %% [markdown]
# # Mathematical Optimization

# %%
def get_ret_vol_sr(weights):
    """
    Takes in weights, returns array or return,volatility, sharpe ratio
    """
    weights = np.array(weights)
    ret = np.sum(log_ret.mean() * weights) * 252
    vol = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
    sr = ret/vol
    return np.array([ret,vol,sr])

# %%
from scipy.optimize import minimize

# %%
help(minimize)
# Out:
# Help on function minimize in module scipy.optimize._minimize:
#
# minimize(fun, x0, args=(), method=None, jac=None, hess=None, hessp=None, bounds=None, constraints=(), tol=None, callback=None, options=None)
#     Minimization of scalar function of one or more variables.
#
#     Parameters
#     ----------
#     fun : callable
#         The objective function to be minimized.
#
#             ``fun(x, *args) -> float``
#
#         where ``x`` is an 1-D array with shape (n,) and ``args``
#         is a tuple of the fixed parameters needed to completely
#         specify the function.
#     x0 : ndarray, shape (n,)
#         Initial guess. Array of real elements of size (n,),
#         where 'n' is the number of independent variables.
#     args : tuple, optional
#         Extra arguments passed to the objective function and its
#         derivatives (`fun`, `jac` and `hess` functions).
#     method : str or callable, optional
#         Type of solver.  Should be one of
#
# ...

# %%
def neg_sharpe(weights):
    return  get_ret_vol_sr(weights)[2] * -1

# %%
def check_sum(weights):
    '''
    Returns 0 if sum of weights is 1.0
    '''
    return np.sum(weights) - 1

# %%
cons = ({'type':'eq','fun': check_sum})

# %%
bounds = ((0,1),(0,1),(0,1),(0,1))

# %%
init_guess=[0.25,0.25,0.25,0.25]

# %%
opt_results = minimize(neg_sharpe,init_guess,method='SLSQP',bounds=bounds,constraints=cons)

# %%
opt_results
# Out:
#      fun: -0.339929085753507
#      jac: array([-0.00018889,  0.08162425,  0.14839961,  0.00046713])
#  message: 'Optimization terminated successfully'
#     nfev: 31
#      nit: 6
#     njev: 6
#   status: 0
#  success: True
#        x: array([0.71420225, 0.        , 0.        , 0.28579775])

# %%
opt_results.x
# Out:
# array([0.71420225, 0.        , 0.        , 0.28579775])

# %%
get_ret_vol_sr(opt_results.x)
# Out:
# array([0.16991245, 0.49984676, 0.33992909])

# %% [markdown]
# # All Optimal Portfolios (Efficient Frontier)

# %%
frontier_y = np.linspace(0,0.3,100)

# %%
def minimize_volatility(weights):
    return  get_ret_vol_sr(weights)[1]

# %%
frontier_volatility = []

for possible_return in frontier_y:
    # function for return
    cons = ({'type':'eq','fun': check_sum},
            {'type':'eq','fun': lambda w: get_ret_vol_sr(w)[0] - possible_return})
    
    result = minimize(minimize_volatility,init_guess,method='SLSQP',bounds=bounds,constraints=cons)  #and here we have two constrain.
    
    frontier_volatility.append(result['fun'])
